# %%
# Arithmetic Oprator

# %%
# step 1: Declare two numbers
a = 15
b = 4

print("Value of a:", a)
print("Value of b:", b)
# Out:
# Value of a: 15
# Value of b: 4

# %%
# step 2: Addition 
add_result = a+b
print("\n1. Addition (a + b):", add_result)
# Out:
# 1. Addition (a + b): 19

# %%
# step 3: Subtraction 
sub_result = a - b
print("\n2. Subraction (a - b):", sub_result)
# Out:
# 2. Subraction (a - b): 11

# %%
# step:4 multiplication
sub_result = a*b
print("\n3. Multikplication (a*b):", sub_result)
# Out:
# 3. Multikplication (a*b): 60

# %%
# step5: Dvision 
div_result = a / b 
print("4. Division (a.b):",div_result)
# Out:
# 4. Division (a.b): 3.75

# %%
# step5: 
floor_result = a // b 
print("4. Floor Dvision (a.b):",floor_result)
# Out:
# 4. Floor Dvision (a.b): 3

# %%
#step 6: floor division 
floor_div = a // b
print("5, floor division(a//b):", floor_div)
# Out:
# 5, floor division(a//b): 3

# %%
# step7: Modules 
mod_result = a % b 
print("4. Modulus (a%b):",mod_result)
# Out:
# 4. Modulus (a%b): 3

# %%
# step8: Exponention 
exp_result = a ** b 
print("8. Exponention  (a**b):",exp_result)
# Out:
# 8. Exponention  (a**b): 50625

# %%
# 2: Comparison Oprator

# Step 1:Declare two numbers
a= 10
b=20

print("Value of a:", a)
print("value of b:", b)
# Out:
# Value of a: 10
# value of b: 20

# %%
# Step 2: Equal to (==)
print("\n1. Eual to ( a==b):", a==b)
# Out:
# 1. Eual to ( a==b): False

# %%
# Step 3: not Equal to (!=)
print("\n2. Eual to ( a!=b):", a!=b)
# Out:
# 2. Eual to ( a!=b): True

# %%
# Step 4: Greater than (>)
print("\n3. Greater than ( a>b):", a>b)
# Out:
# 3. Greater than ( a>b): False

# %%
# Step 5: Less than(>)
print("\n1. Less than( a>b):", a>b)
# Out:
# 1. Less than( a>b): False

# %%
# step 6: Greater than or equal to (>=)
print("5. greater than or equal to (a >= b):", a >=b)
# Out:
# 5. greater than or equal to (a >= b): False

# %%
# step 6: Less than or equal to (<=)
print("5. Less than or equal to (a <= b):", a <=b)
# Out:
# 5. Less than or equal to (a <= b): True

# %%
#Logical Oprator
# srep 1: Dleare variables
x = 10 
y = 20 
z= 5

print("Value ofx:", x)
print("Value ofx:", y)
print("Value ofx:", z)
# Out:
# Value ofx: 10
# Value ofx: 20
# Value ofx: 5

# %%
# Step 2: Using 'and oprator 
print("\n1. Logical AND(x > z and y > x):", x > z and y > x)
# Out:
# 1. Logical AND(x > z and y > x): True

# %%
# Step 2: Using 'Or' oprator 
print("\n1. Logical OR(x > z or y > x):", x > z or y > x)
# Out:
# 1. Logical OR(x > z or y > x): True

# %%
# Step 2: Using 'Not' oprator 
print("\n1. Logical Not(x > z not y > x)):",  x> z not y > x)
# Out:
#   Cell In[12], line 2
#     print("\n1. Logical Not(x > z not y > x)):",  x> z not y > x)
#                                                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Assinment Oprators

# %%
# Step 1: Assin initail value
x = 10
print("Initial value of x:", x)
# Out:
# Initial value of x: 10

# %%
# Step 2: add and assign (+=)
x += 5
print("\n1. Add and Assign (x += 5):", x)
# Out:
# 1. Add and Assign (x += 5): 15

# %%
print(x)
# Out:
# 15

# %%
# Step 3: Subtract and assign (-=)
x -= 3
print("2. Subtract and Assign (x -= 3):", x)
# Out:
# 2. Subtract and Assign (x -= 3): 12

# %%
# Step 4: Multiple and assign (*=)
x *=2
print("3. Multiple and Assign (x *= 2):", x)
# Out:
# 3. Multiple and Assign (x *= 2): 24

# %%
# Step 5: Divide and assign (/=)
x /=4
print("4. Divide and Assign (x /= 4):", x)
# Out:
# 3. Divide and Assign (x /= 4): 0.75

# %%
# Step 6: Floor divide and assign (//=)
x //=2
print("5. Floor divide and Assign (x //= 2):", x)
# Out:
# 5. Floor divide and Assign (x //= 2): 0.0

# %%
# Step 7: Modulus and assign (*=)
x %=2
print("3. Modulus and Assign (x %= 2):", x)
# Out:
# 3. Modulus and Assign (x %= 2): 0.0

# %%
#que

# %%
# 1. Write a Python program to add two numbers entered by the user.
a=15
b=5 
add_result = a+b
print(" Addition(a+b):", add_result);
# Out:
#  Addition(a+b): 20

# %%
# 2. Write a Python program to calculate the area of a rectangle using multiplication (*).
length = 5
width = 4
area = length * width
print("Area of Rectangle =", area);
# Out:
# Area of Rectangle = 20

# %%
# 3. Write a Python program to find the remainder when one number is divided by another using modulus (%).
mod_result = a % b
print(" Modulus(a % b):", mod_result)
# Out:
#  Modulus(a % b): 0

# %%
# 4. Write a Python program to calculate the square and cube of a given number using the exponent (**) operator.
number = 4
square = number**2
cube = number**3
print("Number = ", number)
print("Square =", square) 
print("Cube =", cube)
# Out:
# Number =  4
# Square = 16
# Cube = 64

# %%
# 5. Write a Python program to convert total seconds into minutes and seconds using division and modulus.
total_sec = 160
min = total_sec // 60
seco = total_sec % 60
print("Total sec =",total_sec)
print("min =", min)
print(" Seco =", seco)
# Out:
# Total sec = 160
# min = 2
#  Seco = 40

# %%
# 6. Write a Python program to find the average of 5 numbers using arithmetic operators.
a = 10
b = 20
c = 30
d = 40
e = 50
average = (a+b+c+d+e)/5
print("Average=", average)
# Out:
# Average= 30.0

# %%
# 7. Write a Python program to swap two numbers without using a third variable (use + and - operators).
a = 8
b = 12
print("Before swap:")
print("a =", a)
print("b =", b)

a = a+b
b = a-b
a = a-b
print("After swap")
print("a = ",a)
print("b =", b)
# Out:
# Before swap:
# a = 8
# b = 12
# After swap
# a =  12
# b = 8

# %%
# ----------- COMPARISON / RELATIONAL OPERATORS (7 Questions) -----------

# %%
# 8. Write a Python program to compare two numbers and print which one is greater.
a = 10
b = 5
print(" Greater thanm(a>b):", a>b)
# Out:
#  Greater thanm(a>b): True

# %%
# 9. Write a Python program to check if two numbers are equal or not.
a = 10
b = 3
print(" Equal to (a==b):", a==b)
# Out:
#  Equal to (a==b): False

# %%
# 10. Write a Python program to check if a number is positive, negative, or zero using relational operators.
float(input("Enter a number: "))
if num > 0:
    print("The number is Positive")
elif num < 0:
    print("The number is Negative")
else:
    print("The number is Zero")

# %%
# 11. Write a Python program to check if a person is eligible to vote (age >= 18)
age = 2
print(" Your are eligible to vote(age >=18:", age>=18)
# Out:
#  Your are eligible to vote(age >=18: False

# %%
# 12. Write a Python program to check if a number lies between 1 and 100.
num = 101
print(" The number lies between 1 and 100 num >=1 and num >=100:", num >=1 and num <=100)
# Out:
#  The number lies between 1 and 100 num >=1 and num >=100: False

# %%
# 13. Write a Python program to check if the entered password length is less than or equal to 8.
password = 12345678
print("Password lenght is equal to 8 (password) >= 8:", (password) >= 8)
# Out:
# Password lenght is equal to 8 (password) >= 8: True

# %%
# 14. Write a Python program to compare two strings and print whether they are the same or different.
string1 = a
string2 = b
print(" both are same string (a == b):", a == b)
# Out:
#  both are same string (a == b): False

# %%
#  LOGICAL OPERATORS (8 Questions)

# %%
# 15. Write a Python program to check if a number is positive and even using logical operators.
number = 7
print(" The number is positive  ( number 2 ==0 )and (number % 2 == 0):", number <=0 and  number % 2 == 0)
# Out:
#  The number is positive  ( number 2 ==0 )and (number % 2 == 0): False

# %%
# 16. Write a Python program to check if a number is divisible by both 3 and 5.
number = 15
print(" The number is divisible by both 3 and 5 number % 3 ==0 and number % 5 == 0:", number % 3 ==0 and number % 5 ==0)
# Out:
#  The number is divisible by both 3 and 5 number % 3 ==0 and number % 5 == 0: True

# %%
# 17. Write a Python program to check if a number is divisible by 3 or 7.
number = 21
print(" The number is divisible by both 3 and 5 number % 3 ==0 and number % 7 ==0:", number % 3 ==0 and number % 7 ==0)
# Out:
#  The number is divisible by both 3 and 5 number % 3 ==0 and number % 7 ==0: True

# %%
# 18. Write a Python program to check if a student passes (marks >= 35 in all subjects) using logical AND.
sub1 = 55
sub2 = 20
sub3 = 77
print(" All Student are pass:", sub1 >=35 and sub2 >=35 and sub >=35)
# Out:
#  All Student are pass: False

# %%
# 19. Write a Python program to check if a person can donate blood (age > 18 and weight > 50).
age = 22
weight = 66
print(" donate blood person age > 18 and weight >50:", age > 18 and weight >50)
# Out:
#  donate blood person age > 18 and weight >50: True

# %%
# 20. Write a Python program to check if a number is not between 10 and 20 using logical NOT.
number = 5
print("Not between 10 and 20 num >= 10 not num <=20:", number >= 10)
# Out:
# Not between 10 and 20 num >= 10 not num <=20: False

# %%
# 21. Write a Python program to check login access (username == "admin" and password == "12345").
username = "admin"
password = 12345
print(" Check login access :( username == admin) and (password== 12345):", username == "admin" and password == 12345)
# Out:
#  Check login access :( username == admin) and (password== 12345): True

# %%
# 22. Write a Python program to check if a number is either odd or even using logical operators.
number = 4
print("Check number is even or odd (number % 2 == 0) or (number % 2 !=0):", number % 2 == 0 or number % 2 !=0)
# Out:
# Check number is even or odd (number % 2 == 0) or (number % 2 !=0): True

# %%
# ASSIGNMENT OPERATORS

# %%
 # 23. Write a Python program to demonstrate the use of += by adding 10 to a variable.
number =20
number += 10
print(" Value after adding (number += 5):", number )
# Out:
#  Value after adding (number += 5): 30

# %%
# 24. Write a Python program to demonstrate the use of -= by subtracting 5 from a variable.
number = 3
number -= 2
print(" Value after adding (number -=2):", number)
# Out:
#  Value after adding (number -=2): 1

# %%
# 25. Write a Python program to multiply a variable by 3 using *=.
a = 15
a *= 3
print(" Multiply a variable( a *= 2):",a)
# Out:
#  Multiply a variable( a *= 2): 45

# %%
# 26. Write a Python program to divide a variable by 2 using /=.
a = 5
a /= 2
print(" Divide and assign (a /=2):", a)
# Out:
#  Divide and assign (a /=2): 2.5

# %%
# 27. Write a Python program to find the remainder using %= assignment operator.
a= 5
a %= 2
print(" Divide and assign (a %=2):", a)
# Out:
#  Divide and assign (a %=2): 1

# %%
# 28. Write a Python program to calculate the square of a number using **=.
a = 3
a **= 3
print(" Divide and assign (a **=3):", a)
# Out:
#  Divide and assign (a **=3): 27

# %%
# 29. Write a Python program where the user enters a value, and you keep doubling it using *= until it exceeds 100
a = 
a *= 3                                                     
print(" Divide and assign (a *=3):", a)
# Out:
#   Cell In[1], line 3
#     a = <= 100:
#         ^
# SyntaxError: invalid syntax

# %%
num = int(input("enter your number:"))
while num <= 100:
    num *= 2
print(" value :",num)
# Out:
# enter your number: 15
#  value : 120

# %%
# 30. Write a Python program that performs multiple assignment operations (+=, -=, *=, /=) 
# step-by-step on one variable and prints results after each step.
a = 10
a += 5
print("result += :", a)
a -= 3
print("result -= :", a)
a *= 2
print("result *= :", a)
a /= 4
print("result /= :", a)
# Out:
# result += : 15
# result -= : 12
# result *= : 24
# result /= : 6.0

# %%
for i in range(5, 0 ,-1):
    print("*" * i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
rows = 5            
for i in range(1, rows + 1):
    print(" " * (rows - i) + "*"*(2*i -1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
rows = 5 
for i in range(1, rows + 1): # (1,5+1) = (1,6) = 1,2,3,4,5 
    print(" "*(rows-i) + "*"*(2*i -1)) # i = 1  " " * (5-1) = 4 , 4 * ""  +  "*" * (2 * 1 -1) = "*" * 1= * 
                                        # i = 2  " * (5-2) = 3, 3 * ""  +  "*" * (2 * 2 -1) = "*" * 3=
