# %%
# create a set 
# A set is create using curly braces{} or the set() constructor 
# it auotomaticaly

# %%
my_set = { 1, 2, 3, 4, 3, 5}

# %%
print("Set elements:", my_set)
# Out:
# Set elements: {1, 2, 3, 4, 5}

# %%
# create an empty set

# %%
empty_set = set()

# %%
print("Empty set:", empty_set)
# Out:
# Empty set: set()

# %%
# Adding Elements to a set
# we can use add() for single or update() for multiple

# %%
fruits ={"apple", "banana", 1, 0.8}

# %%
fruits.add("cherry")

# %%
print("After adding single fruits:", fruits)
# Out:
# After adding single fruits: {0.8, 1, 'cherry', 'apple', 'banana'}

# %%
fruits.update(["mango", "orange"])

# %%
print("After adding multiple fruits:", fruits)
# Out:
# After adding multiple fruits: {0.8, 1, 'cherry', 'apple', 'orange', 'banana', 'mango'}

# %%
# Removing Elemen 
# threre are servaral ways to remove elements : remove(), discard(), pop()

# %%
numbers={ 10, 20, 30, 40, 50}

# %%
print(numbers)
# Out:
# {50, 20, 40, 10, 30}

# %%
numbers.remove(50)

# %%
print ("After remove():", numbers)
# Out:
# After remove(): {20, 40, 10, 30}

# %%
numbers.remove(100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 numbers.remove(100)
#
# KeyError: 100

# %%
numbers.discard(100)

# %%
print("After discard():", numbers)
# Out:
# After discard(): {20, 40, 10, 30}

# %%
popped_item = numbers.pop()

# %%
print("After pop():", numbers)
# Out:
# After pop(): {40, 10, 30}

# %%
print("popped element:", popped_item)
# Out:
# popped element: 20

# %%
# set oprations (mathmatical)
# set can perform oprations like union, intresection, difference, symmetric

# %%
A = {1, 2, 3,4}

# %%
B ={ 3, 4, 5, 6}

# %%
print("Union (A|B ):", A|B)
# Out:
# Union (A|B ): {1, 2, 3, 4, 5, 6}

# %%
print("Intersection (A & B ):", A & B)
# Out:
# Intersection (A & B ): {3, 4}

# %%
print("Difference (A-B):", B-A)
# Out:
# Difference (A-B): {5, 6}

# %%
print("Symmetric Difference (A^B):", A^B)
# Out:
# Symmetric Difference (A^B): {1, 2, 5, 6}

# %%
# memebership testing 
# you can check if an item exists in a set using in or not in

# %%
cities = {"Delhi", "mumbai", "chennai", "kolkata"}

# %%
print(" Is 'Delhi' in cities?", "Delhi" in cities)
# Out:
#  Is 'Delhi' in cities? True

# %%
print(" Is 'pune' not in cities?", "pune" not in cities)
# Out:
#  Is 'pune' not in cities? True

# %%
# Interating Throgh a Set
# Even thogh sets are unordered we can still loop throgh them

# %%
for item in cities:
    print("city:", item)
# Out:
# city: mumbai
# city: kolkata
# city: Delhi
# city: chennai

# %%
# converyting other data type set

# %%
numbers_list =[1, 2, 2, 3, 4, 4, 5]

# %%
unique_numbers = set(numbers_list)

# %%
print("unique numbers:", unique_numbers)
# Out:
# unique numbers: {1, 2, 3, 4, 5}

# %%
# frozen set immutable 
# a frozen is like a set but cannot be change after creation

# %%
frozen = frozenset(["AI", "Data Science", "ML"])

# %%
print("frozen set:", frozen)
# Out:
# frozen set: frozenset({'Data Science', 'AI', 'ML'})

# %%
frozen.add("Deep Learning")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 frozen.add("Deep Learning")
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
site1_visitors = {"Alice","Bob", "Charli", "David"}
site2_visitors = {" Charlie", "eve", "Frank", "Alice"}

# %%
unique_visitors = site1_visitors | site2_visitors

# %%
print("Unique_visitors:", unique_visitors)
# Out:
# Unique_visitors: {'David', 'Charli', 'Bob', 'Frank', 'eve', ' Charlie', 'Alice'}

# %%
common_visitors = site1_visitors & site2_visitors

# %%
print("Common visitors:", common_visitors)
# Out:
# Common visitors: {'Alice'}

# %%
exclusive_Visitors = site1_visitors ^ site2_visitors

# %%
print("Visitors exclusive to one site:",exclusive_Visitors )
# Out:
# Visitors exclusive to one site: {'Charli', 'Bob', 'Frank', 'eve', ' Charlie', 'David'}

# %%
# Len()

students = {"rahul", "sneha", "amit", "priya", "rahul"}

# %%
print("Total students (unique):", len(students))
# Out:
# Total students (unique): 4

# %%
# max() and min()
numbers = {12, 45, 23, 9, 56, 17}

# %%
print("Maximum value:", max(numbers))
# Out:
# Maximum value: 56

# %%
print("Mimimum value:", min(numbers))
# Out:
# Mimimum value: 9

# %%
#sum() 
sales = {1200, 1500, 1800, 1500}

# %%
print("Total unique sales amount:", sum(sales))
# Out:
# Total unique sales amount: 4500

# %%
# sorted() - return sorted list from the set

data = {9, 1, 5, 3, 2, 8}

# %%
sorted_data = sorted(data)

# %%
print("Sorted set elemnet:", sorted_data)
# Out:
# Sorted set elemnet: [1, 2, 3, 5, 8, 9]

# %%
sorted_numbers_desc = sorted(data, reverse = True)

# %%
print("Sorted set elements:", sorted_numbers_desc)
# Out:
# Sorted set elements: [9, 8, 5, 3, 2, 1]

# %%
# any() and all() logical evalution on set  elements

binary_set = {1, 0, 1}

# %%
print("Any true value?", any(binary_set))  # true if at least one elements
# Out:
# Any true value? True

# %%
print("All true values?", all(binary_set))
# Out:
# All true values? False

# %%
# issubset() and issuperset()

A= {1,2, 3}
B= {1, 2, 3, 4,5}

# %%
print("A is subset of b:", A.issubset(B))
print("B is superset of A:", B.issuperset(A))
# Out:
# A is subset of b: True
# B is superset of A: True

# %%
# isdisjoint()

set1 = {"cat", "dog", "rabbit"}
set2 ={ "lion", "tiger", "leopard"}

# %%
print(" are the two sets disjoint?", set1. isdisjoint(set2))
# Out:
#  are the two sets disjoint? True

# %%
# copy() create a duplicate of a set 

original_set = {"python", "AI", "ML"}

# %%
duplicate_set = original_set.copy()

# %%
print("Copied set:", duplicate_set)
# Out:
# Copied set: {'python', 'AI', 'ML'}

# %%
# del()

test_set = {10, 20, 30}

# %%
print("Before deletion:", test_set)
# Out:
# Before deletion: {10, 20, 30}

# %%
del test_set

# %%
print("After deletion:", test_set)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 print("After deletion:", test_set)
#
# NameError: name 'test_set' is not defined

# %%
# Que

# %%
# 1. Create a set containing five different country names and print it.
country = {"India", "America", "Uk", "Canada"}
print(country)
# Out:
# {'America', 'Canada', 'Uk', 'India'}

# %%
# 2. Create a set with duplicate numbers and print it to see how duplicates are handled.
Numbers = {1,2, 3, 4, 5,5,6,3}
print(Numbers)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# 3. Use the set() constructor to create a set from a list of fruits.
Fruits = {"Mango", "Banana", "Papaya","Apple"}
Fruits_set = set(Fruits)
print(Fruits)
# Out:
# {'Mango', 'Banana', 'Papaya', 'Apple'}

# %%
# 4. Add a new element into an existing set using add() method
Fruits = {"Mango", "Banana", "Papaya","Apple"}
Fruits.add("Kivi")
print("After adding single Fruits:", Fruits)
# Out:
# After adding single Fruits: {'Banana', 'Mango', 'Kivi', 'Apple', 'Papaya'}

# %%
# 5. Add multiple elements into a set using update() method.
Fruits.update(["mango", "orange"])
print("After adding multiple fruits:", Fruits)
# Out:
# After adding multiple fruits: {'Banana', 'mango', 'Mango', 'Kivi', 'orange', 'Apple', 'Papaya'}

# %%
# 6. Try adding a duplicate element to the set and check if it changes.
Fruits.add("Mango")
print("After adding single Fruits:", Fruits)
# Out:
# After adding single Fruits: {'Banana', 'mango', 'Mango', 'Kivi', 'orange', 'Apple', 'Papaya'}

# %%
# 7. Remove an element from a set using remove() method.
Fruits = {"Mango", "Banana", "Papaya","Apple"}
Fruits.remove("Papaya")
print(Fruits)
# Out:
# {'Banana', 'Mango', 'Apple'}

# %%
# 8. Remove an element safely using discard() without raising an error.
Fruits.discard("Apple")
print("After discard", Fruits)
# Out:
# After discard {'Banana', 'Mango'}

# %%
# 9. Remove a random element using pop() and print both removed and remaining elements.
removed = Fruits.pop()
print("Removed:",removed)
print("Remaning:",Fruits.pop)
# Out:
# Removed: Mango
# Remaning: <built-in method pop of set object at 0x000002B91A93ECE0>

# %%
# 10. Clear all elements from a set using clear() and print it.
Fruits = {"Mango", "Banana", "Papaya","Apple"}
print(Fruits)
Fruits.clear()
print(Friui
# Out:
# {'Banana', 'Papaya', 'Mango', 'Apple'}

# %%
# 11. Create two sets of numbers and perform union operation.
set_1 = {1, 2, 3, 4}
set_2 = {4, 6, 6, 8}
print("Union (set_1|set_2 ):", set_1|set_2)
# Out:
# Union (set_1|set_2 ): {1, 2, 3, 4, 6, 8}

# %%
# 12. Perform intersection between two sets to find common element
print("Intersection (set_1 & set_2):", set_1 & set_2)
# Out:
# Intersection (set_1 & set_2): {4}

# %%
# 13. Perform difference between two sets to find unique elements from the first set.
print("Difference (set_1-set_2):", set_2-set_1)
# Out:
# Difference (set_1-set_2): {8, 6}

# %%
# 14. Perform symmetric difference between two sets and print the result.
print("Symmetric Difference (set_1^set_2):", set_1^set_2)
# Out:
# Symmetric Difference (set_1^set_2): {1, 2, 3, 6, 8}

# %%
# 15. Check if one set is a subset of another using issubset() method.
set_1 = { 1, 2, 3}
set_2 = { 1, 2, 3, 4, 5}
print(set_1.issubset(set_2))
# Out:
# True

# %%
# 16. Check if one set is a superset of another using issuperset() method.
set_1 = { 1, 2, 3}
set_2 = { 1, 2, 3, 4, 5}
print(set_2.issuperset(set_1))
# Out:
# True

# %%
# 17. Check if two sets have no common elements using isdisjoint() method.
set1 = {"cat", "dog","rabbit"}
set2 = {"lion", "tiger", "leopard"}
print("Are the two sets disjoint?", set1.isdisjoint(set2))
# Out:
# Are the two sets disjoint? True

# %%
# 18. Use in keyword to check if a particular element exists in a set.
my_set = {"apple","banana","mango"} 
print("apple" in my_set)
# Out:
# True

# %%
# 19. Use not in keyword to check if an element does not exist in a set.
print("orange" not in my_set)
# Out:
# True

# %%
# 20. Find the total number of elements in a set using len().
a = { 1, 2, 3}
b = { 4, 5, 7, 8,}
print(len(a))
# Out:
# 3

# %%
# 21. Find the maximum and minimum element from a numeric set using max() and min().
numbers = {10, 5, 30, 20}
print("maximum:", max(numbers))
print("minimum:", min(numbers))
# Out:
# maximum: 30
# minimum: 5

# %%
# 22. Find the sum of all elements from a numeric set using sum().
sum(numbers)
# Out:
# 65

# %%
# 23. Convert a set into a sorted list in ascending order using sorted().
numbers = {0,22, 11, 66, 2, 3 }
sorted_list = sorted(numbers)
print(sorted_list)
# Out:
# [0, 2, 3, 11, 22, 66]

# %%
# 24. Sort a set in descending order using sorted() with reverse=True.
numbers_set = { 10, 3, 9, 2, 1, 5, 7,}
sorted_list = sorted(numbers_set,reverse=True)
print(sorted_list)
# Out:
# [10, 9, 7, 5, 3, 2, 1]

# %%
# 25. Use any() to check if at least one True value exists in a Boolean set.
boolean_set = {False, False, True}
result = any(boolean_set)
print(result)
# Out:
# True

# %%
# 26. Use all() to check if all values in a Boolean set are True.
boolean_set = {False, False, True, True}
result = all(boolean_set)
print(result)
# Out:
# False

# %%
# 27. Copy a set using copy() and verify both sets are independent.
set1 = {10, 20, 30,40}
set2 = set1.copy()
print("original set:",set1)
print("copied set:", set2)
set2.add(30)
# Out:
# original set: {40, 10, 20, 30}
# copied set: {40, 10, 20, 30}

# %%
# 28. Delete a set completely using del keyword and observe the result.
t_set = {10, 20, 30}
print(t_set)
# Out:
# {10, 20, 30}

# %%
del t_set
print(t_set)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 del t_set
#       2 print(t_set)
#
# NameError: name 't_set' is not defined

# %%
# 29. Convert a list with duplicate values into a set to remove duplicates.
numbers_list =[1, 2, 2, 3, 4, 4, 5]
unique_numbers = set(numbers_list)
print("unique numbers:", unique_numbers)
# Out:
# unique numbers: {1, 2, 3, 4, 5}

# %%
# 30. Create two sets of student names (from two different classes) and find:
# a) Common students (intersection)
# b) Students only in class A (difference)
#c) All unique students (union)

class_1 = {" Amit", "Neha", "Rahul"}
class_2 = {"Rahul", "Pooja", "Neha"}

print("Intersection (class_1 & class_2):", class_1 & class_2) #   intersectionv(donhi class madhle  common students)

print("Difference (class_1 - class_2):", class_1 - class_2)    # difference (only class_1 che students)

print("Union (class_1|class_2):",class_1 | class_2 )       # union (donhi classes madhle unique students)
# Out:
# Intersection (class_1 & class_2): {'Rahul', 'Neha'}
# Difference (class_1 - class_2): {' Amit'}
# Union (class_1|class_2): {'Rahul', ' Amit', 'Pooja', 'Neha'}
