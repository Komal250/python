# %%
#  Example : Check if a number is even or odd

number = 10 # you can change this value to test 

if number % 2 == 0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# The number is even

# %%
# Example 1 : Cheaking if a number is positve 

number = int(input("Enter a number:"))

if number > 0:
    print("The number is positve")
# Out:
# Enter a number: 7
# The number is positve

# %%
# Exmaple 2: Checking if a number is even or odd 

number = int(input("Enter a number:"))

if number % 2 == 0:
    print("The number is even")
else: 
    print("The number is odd")
# Out:
# Enter a number: 6
# The number is even

# %%
# Example 3 : Grading system

marks = int(input("Enter your marks: "))

if marks >=90:
    print("Grade: A")
elif marks >=75:
    print("Grade: B")
elif marks >=60:
    print("Grade: ")
else:
    print("Grade: fail")
